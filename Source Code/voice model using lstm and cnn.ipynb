# %%
import numpy as np
import soundfile
import librosa
import glob
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, LSTM, Dropout, TimeDistributed

def extract_features(file_name, mfcc, chroma, mel):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate = sound_file.samplerate
        if chroma:
            stft = np.abs(librosa.stft(X))
        result = []
        if mfcc:
            mfccs = librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40)
            mfccs_mean = np.mean(mfccs, axis=1)
            result.append(mfccs_mean)
        if chroma:
            chroma = librosa.feature.chroma_stft(S=stft, sr=sample_rate)
            chroma_mean = np.mean(chroma, axis=1)
            result.append(chroma_mean)
        if mel:
            mel = librosa.feature.melspectrogram(y=X, sr=sample_rate)
            mel_mean = np.mean(mel, axis=1)
            result.append(mel_mean)
    max_len = max(feature.shape[0] for feature in result)
    result = [np.pad(feature, (0, max_len - feature.shape[0])) if feature.shape[0] < max_len else feature[:max_len] for feature in result]
    return np.concatenate(result, axis=0)

def load_data(test_size=0.2):
    x, y = [], []
    for file in glob.glob("D:\\D\\Sudharsan\\Mini project\\ravdess\\Actor_*\\*.wav"):
        file_name = os.path.basename(file)
        emotion = emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            continue
        feature = extract_features(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append(emotion)
    
    # Convert string labels to integer labels
    label_encoder = LabelEncoder()
    y = label_encoder.fit_transform(y)
    
    return train_test_split(x, y, test_size=test_size, random_state=9)

emotions = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}

# Define emotions to observe
observed_emotions = ['neutral', 'calm','happy', 'sad','angry', 'fearful', 'disgust', 'surprised']

# Split the dataset
x_train, x_test, y_train, y_test = load_data(test_size=0.25)
# Determine the number of classes in your dataset
num_classes = len(np.unique(y_train))

# Convert labels to one-hot encoded format
y_train = to_categorical(y_train, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)

# Pad or truncate sequences to a fixed length
max_sequence_length = 100
# Reshape sequences to have consistent length
x_train = np.array([np.resize(sequence, (max_sequence_length,)) for sequence in x_train])
x_test = np.array([np.resize(sequence, (max_sequence_length,)) for sequence in x_test])

# Pad sequences to a fixed length
x_train = np.expand_dims(x_train, axis=-1)  # Add channel dimension
x_test = np.expand_dims(x_test, axis=-1)  # Add channel dimension

# Define the CNN-LSTM model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(max_sequence_length, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(TimeDistributed(Flatten()))
model.add(LSTM(units=128))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=100, batch_size=32, validation_data=(x_test, y_test))

# Save the trained model
model.save('voice_emotion_cnn_lstm.h5')
# Out:
# c:\Users\Sudharsan Sayeeram\AppData\Local\Programs\Python\Python39\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=2
#   warnings.warn(
# c:\Users\Sudharsan Sayeeram\AppData\Local\Programs\Python\Python39\lib\site-packages\librosa\core\pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# Epoch 1/100
# 34/34 [==============================] - 16s 47ms/step - loss: 2.0716 - accuracy: 0.1426 - val_loss: 2.0670 - val_accuracy: 0.1250
# Epoch 2/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.0380 - accuracy: 0.1694 - val_loss: 2.0512 - val_accuracy: 0.1667
# Epoch 3/100
# 34/34 [==============================] - 1s 17ms/step - loss: 2.0125 - accuracy: 0.1954 - val_loss: 2.0365 - val_accuracy: 0.2000
# Epoch 4/100
# 34/34 [==============================] - 1s 18ms/step - loss: 1.9445 - accuracy: 0.2241 - val_loss: 2.0710 - val_accuracy: 0.1833
# Epoch 5/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.9180 - accuracy: 0.2343 - val_loss: 1.9541 - val_accuracy: 0.2722
# Epoch 6/100
# 34/34 [==============================] - 1s 19ms/step - loss: 1.8968 - accuracy: 0.2343 - val_loss: 1.9385 - val_accuracy: 0.2472
# Epoch 7/100
# 34/34 [==============================] - 1s 20ms/step - loss: 1.8933 - accuracy: 0.2778 - val_loss: 1.9795 - val_accuracy: 0.2556
# Epoch 8/100
# 34/34 [==============================] - 1s 18ms/step - loss: 1.8670 - accuracy: 0.2602 - val_loss: 1.9459 - val_accuracy: 0.2583
# Epoch 9/100
# 34/34 [==============================] - 1s 18ms/step - loss: 1.8615 - accuracy: 0.2898 - val_loss: 1.8962 - val_accuracy: 0.2500
# Epoch 10/100
# 34/34 [==============================] - 1s 18ms/step - loss: 1.8265 - accuracy: 0.2778 - val_loss: 1.8678 - val_accuracy: 0.2611
# Epoch 11/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8091 - accuracy: 0.2935 - val_loss: 1.9107 - val_accuracy: 0.2639
# Epoch 12/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.8053 - accuracy: 0.2731 - val_loss: 1.8525 - val_accuracy: 0.2750
# Epoch 13/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.7826 - accuracy: 0.3204 - val_loss: 1.9458 - val_accuracy: 0.2556
# Epoch 14/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.7885 - accuracy: 0.3019 - val_loss: 1.8531 - val_accuracy: 0.2667
# Epoch 15/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.7845 - accuracy: 0.3194 - val_loss: 1.8457 - val_accuracy: 0.2778
# Epoch 16/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.7729 - accuracy: 0.3296 - val_loss: 1.8304 - val_accuracy: 0.3056
# Epoch 17/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.7485 - accuracy: 0.3435 - val_loss: 1.8189 - val_accuracy: 0.2972
# Epoch 18/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.7587 - accuracy: 0.3259 - val_loss: 1.8578 - val_accuracy: 0.2944
# Epoch 19/100
# 34/34 [==============================] - 1s 15ms/step - loss: 1.7422 - accuracy: 0.3204 - val_loss: 1.9053 - val_accuracy: 0.2778
# Epoch 20/100
# 34/34 [==============================] - 1s 15ms/step - loss: 1.7716 - accuracy: 0.3241 - val_loss: 1.8335 - val_accuracy: 0.3056
# Epoch 21/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.7415 - accuracy: 0.3213 - val_loss: 1.8193 - val_accuracy: 0.3028
# Epoch 22/100
# 34/34 [==============================] - 0s 15ms/step - loss: 1.7481 - accuracy: 0.3324 - val_loss: 1.8230 - val_accuracy: 0.2722
# Epoch 23/100
# 34/34 [==============================] - 0s 15ms/step - loss: 1.7294 - accuracy: 0.3352 - val_loss: 1.8171 - val_accuracy: 0.2722
# Epoch 24/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.7196 - accuracy: 0.3250 - val_loss: 1.8045 - val_accuracy: 0.3083
# Epoch 25/100
# 34/34 [==============================] - 1s 20ms/step - loss: 1.6674 - accuracy: 0.3620 - val_loss: 1.7678 - val_accuracy: 0.3194
# Epoch 26/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.6771 - accuracy: 0.3630 - val_loss: 1.7802 - val_accuracy: 0.3167
# Epoch 27/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.6536 - accuracy: 0.3713 - val_loss: 1.8531 - val_accuracy: 0.3167
# Epoch 28/100
# 34/34 [==============================] - 1s 15ms/step - loss: 1.6867 - accuracy: 0.3685 - val_loss: 1.8054 - val_accuracy: 0.3389
# Epoch 29/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.6544 - accuracy: 0.3694 - val_loss: 1.7852 - val_accuracy: 0.3472
# Epoch 30/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.6399 - accuracy: 0.3824 - val_loss: 1.7716 - val_accuracy: 0.3528
# Epoch 31/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.6226 - accuracy: 0.3815 - val_loss: 1.8217 - val_accuracy: 0.3667
# Epoch 32/100
# 34/34 [==============================] - 1s 15ms/step - loss: 1.6588 - accuracy: 0.3750 - val_loss: 1.8191 - val_accuracy: 0.2917
# Epoch 33/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.6421 - accuracy: 0.3907 - val_loss: 1.7245 - val_accuracy: 0.3611
# Epoch 34/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.5922 - accuracy: 0.4037 - val_loss: 1.7454 - val_accuracy: 0.3889
# Epoch 35/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.5299 - accuracy: 0.4231 - val_loss: 1.7353 - val_accuracy: 0.3944
# Epoch 36/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.5220 - accuracy: 0.4389 - val_loss: 1.6865 - val_accuracy: 0.3917
# Epoch 37/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.5617 - accuracy: 0.4259 - val_loss: 1.6773 - val_accuracy: 0.3889
# Epoch 38/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.5069 - accuracy: 0.4296 - val_loss: 1.7010 - val_accuracy: 0.3972
# Epoch 39/100
# 34/34 [==============================] - 1s 18ms/step - loss: 1.4709 - accuracy: 0.4537 - val_loss: 1.6854 - val_accuracy: 0.3861
# Epoch 40/100
# 34/34 [==============================] - 1s 20ms/step - loss: 1.5264 - accuracy: 0.4380 - val_loss: 1.6765 - val_accuracy: 0.3889
# Epoch 41/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.5176 - accuracy: 0.4278 - val_loss: 1.7324 - val_accuracy: 0.3694
# Epoch 42/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.4809 - accuracy: 0.4602 - val_loss: 1.7275 - val_accuracy: 0.3667
# Epoch 43/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.4651 - accuracy: 0.4639 - val_loss: 1.7436 - val_accuracy: 0.4083
# Epoch 44/100
# 34/34 [==============================] - 1s 15ms/step - loss: 1.4309 - accuracy: 0.4704 - val_loss: 1.6978 - val_accuracy: 0.3833
# Epoch 45/100
# 34/34 [==============================] - 1s 15ms/step - loss: 1.4285 - accuracy: 0.4694 - val_loss: 1.6508 - val_accuracy: 0.4028
# Epoch 46/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.4184 - accuracy: 0.4843 - val_loss: 1.6973 - val_accuracy: 0.3750
# Epoch 47/100
# 34/34 [==============================] - 1s 19ms/step - loss: 1.4097 - accuracy: 0.4713 - val_loss: 1.6629 - val_accuracy: 0.4111
# Epoch 48/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.3719 - accuracy: 0.5000 - val_loss: 1.6489 - val_accuracy: 0.4139
# Epoch 49/100
# 34/34 [==============================] - 1s 15ms/step - loss: 1.3622 - accuracy: 0.5056 - val_loss: 1.6958 - val_accuracy: 0.3806
# Epoch 50/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.3471 - accuracy: 0.5056 - val_loss: 1.7041 - val_accuracy: 0.3694
# Epoch 51/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.2935 - accuracy: 0.5380 - val_loss: 1.6652 - val_accuracy: 0.4083
# Epoch 52/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.3176 - accuracy: 0.5074 - val_loss: 1.7764 - val_accuracy: 0.3722
# Epoch 53/100
# 34/34 [==============================] - 1s 15ms/step - loss: 1.3048 - accuracy: 0.5194 - val_loss: 1.7243 - val_accuracy: 0.4000
# Epoch 54/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.3832 - accuracy: 0.5056 - val_loss: 1.7085 - val_accuracy: 0.3778
# Epoch 55/100
# 34/34 [==============================] - 1s 15ms/step - loss: 1.3409 - accuracy: 0.5157 - val_loss: 1.7280 - val_accuracy: 0.3944
# Epoch 56/100
# 34/34 [==============================] - 0s 15ms/step - loss: 1.2650 - accuracy: 0.5352 - val_loss: 1.6822 - val_accuracy: 0.3972
# Epoch 57/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.2654 - accuracy: 0.5630 - val_loss: 1.6621 - val_accuracy: 0.4111
# Epoch 58/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.2018 - accuracy: 0.5435 - val_loss: 1.7143 - val_accuracy: 0.4250
# Epoch 59/100
# 34/34 [==============================] - 1s 18ms/step - loss: 1.2231 - accuracy: 0.5611 - val_loss: 1.7021 - val_accuracy: 0.4167
# Epoch 60/100
# 34/34 [==============================] - 1s 18ms/step - loss: 1.2116 - accuracy: 0.5556 - val_loss: 1.5947 - val_accuracy: 0.4389
# Epoch 61/100
# 34/34 [==============================] - 0s 15ms/step - loss: 1.1567 - accuracy: 0.5759 - val_loss: 1.7070 - val_accuracy: 0.4083
# Epoch 62/100
# 34/34 [==============================] - 1s 15ms/step - loss: 1.1995 - accuracy: 0.5694 - val_loss: 1.7493 - val_accuracy: 0.4111
# Epoch 63/100
# 34/34 [==============================] - 1s 15ms/step - loss: 1.1262 - accuracy: 0.6019 - val_loss: 1.6462 - val_accuracy: 0.4417
# Epoch 64/100
# 34/34 [==============================] - 0s 14ms/step - loss: 1.1055 - accuracy: 0.6074 - val_loss: 1.6884 - val_accuracy: 0.4472
# Epoch 65/100
# 34/34 [==============================] - 1s 19ms/step - loss: 1.1287 - accuracy: 0.5944 - val_loss: 1.6273 - val_accuracy: 0.4667
# Epoch 66/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.0627 - accuracy: 0.6148 - val_loss: 1.7434 - val_accuracy: 0.4444
# Epoch 67/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.0597 - accuracy: 0.6231 - val_loss: 1.6932 - val_accuracy: 0.4556
# Epoch 68/100
# 34/34 [==============================] - 1s 18ms/step - loss: 1.0532 - accuracy: 0.6130 - val_loss: 1.7445 - val_accuracy: 0.4361
# Epoch 69/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.0415 - accuracy: 0.6231 - val_loss: 1.6593 - val_accuracy: 0.4528
# Epoch 70/100
# 34/34 [==============================] - 1s 19ms/step - loss: 1.0318 - accuracy: 0.6287 - val_loss: 1.6838 - val_accuracy: 0.4417
# Epoch 71/100
# 34/34 [==============================] - 1s 17ms/step - loss: 1.0115 - accuracy: 0.6398 - val_loss: 1.7887 - val_accuracy: 0.4111
# Epoch 72/100
# 34/34 [==============================] - 1s 22ms/step - loss: 0.9590 - accuracy: 0.6519 - val_loss: 1.7448 - val_accuracy: 0.4528
# Epoch 73/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.9082 - accuracy: 0.6833 - val_loss: 1.7892 - val_accuracy: 0.4583
# Epoch 74/100
# 34/34 [==============================] - 1s 18ms/step - loss: 1.0336 - accuracy: 0.6231 - val_loss: 1.7959 - val_accuracy: 0.4333
# Epoch 75/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.9392 - accuracy: 0.6787 - val_loss: 1.8077 - val_accuracy: 0.4472
# Epoch 76/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.9682 - accuracy: 0.6574 - val_loss: 1.7484 - val_accuracy: 0.4722
# Epoch 77/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.8608 - accuracy: 0.7046 - val_loss: 1.8079 - val_accuracy: 0.4667
# Epoch 78/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.9387 - accuracy: 0.6741 - val_loss: 1.7875 - val_accuracy: 0.4639
# Epoch 79/100
# 34/34 [==============================] - 1s 16ms/step - loss: 1.1616 - accuracy: 0.5926 - val_loss: 1.7321 - val_accuracy: 0.4667
# Epoch 80/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.8863 - accuracy: 0.6898 - val_loss: 1.7562 - val_accuracy: 0.4556
# Epoch 81/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.8171 - accuracy: 0.7278 - val_loss: 1.7884 - val_accuracy: 0.4417
# Epoch 82/100
# 34/34 [==============================] - 0s 15ms/step - loss: 0.8343 - accuracy: 0.7120 - val_loss: 1.8466 - val_accuracy: 0.4750
# Epoch 83/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.7936 - accuracy: 0.7222 - val_loss: 1.8156 - val_accuracy: 0.4722
# Epoch 84/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.7738 - accuracy: 0.7380 - val_loss: 1.9067 - val_accuracy: 0.4694
# Epoch 85/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.8256 - accuracy: 0.7167 - val_loss: 1.8160 - val_accuracy: 0.4694
# Epoch 86/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.8336 - accuracy: 0.7130 - val_loss: 1.7582 - val_accuracy: 0.4972
# Epoch 87/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.6540 - accuracy: 0.7778 - val_loss: 1.9182 - val_accuracy: 0.4750
# Epoch 88/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.6283 - accuracy: 0.7852 - val_loss: 1.9491 - val_accuracy: 0.4639
# Epoch 89/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.6986 - accuracy: 0.7704 - val_loss: 2.0163 - val_accuracy: 0.4806
# Epoch 90/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.8525 - accuracy: 0.7037 - val_loss: 2.0643 - val_accuracy: 0.3972
# Epoch 91/100
# 34/34 [==============================] - 1s 15ms/step - loss: 0.8663 - accuracy: 0.7028 - val_loss: 1.9314 - val_accuracy: 0.4500
# Epoch 92/100
# 34/34 [==============================] - 0s 15ms/step - loss: 0.6817 - accuracy: 0.7713 - val_loss: 2.0038 - val_accuracy: 0.4361
# Epoch 93/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.8010 - accuracy: 0.7352 - val_loss: 1.8954 - val_accuracy: 0.4639
# Epoch 94/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.6309 - accuracy: 0.7778 - val_loss: 1.8755 - val_accuracy: 0.4667
# Epoch 95/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.5725 - accuracy: 0.8148 - val_loss: 2.0464 - val_accuracy: 0.4556
# Epoch 96/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.6141 - accuracy: 0.7917 - val_loss: 2.0714 - val_accuracy: 0.4444
# Epoch 97/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.5382 - accuracy: 0.8111 - val_loss: 2.0525 - val_accuracy: 0.4778
# Epoch 98/100
# 34/34 [==============================] - 0s 14ms/step - loss: 0.5015 - accuracy: 0.8287 - val_loss: 2.0490 - val_accuracy: 0.4833
# Epoch 99/100
# 34/34 [==============================] - 0s 15ms/step - loss: 0.4768 - accuracy: 0.8259 - val_loss: 2.0961 - val_accuracy: 0.4833
# Epoch 100/100
# 34/34 [==============================] - 1s 17ms/step - loss: 0.5610 - accuracy: 0.7954 - val_loss: 2.3743 - val_accuracy: 0.4583
